# %%
# Install the necessary pytorch packages to work with mac gpus
# !conda install pytorch torchvision torchaudio -c pytorch-nightly -y
# Out:
# ...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# | DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/osx-arm64/current_repodata.json HTTP/1.1" 304 0
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# ...

# %%
# Install the ultralytics package using conda
# !conda install -c conda-forge ultralytics -y

# %%
# Imports
import torch
import matplotlib.pyplot as plt
from PIL import Image
from ultralytics import YOLO

# %%
# Change "mps" to "cuda" if running on nvidia gpu, or leave to run on cpu.
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
model11n = YOLO("yolo11n.pt").to(device)

# %%
model11x = YOLO("yolo11x.pt").to(device)

# %%
resultn = model11n.predict(source="testing_files/vtest.avi", save=True, project="runs/predict", name="output_vtestn")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# WARNING ⚠️ NMS time limit 2.050s exceeded
# video 1/1 (frame 1/795) /Users/cazza/Documents/UTS/CS 2/PedestrianProject/testing_files/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 248.2ms
# video 1/1 (frame 2/795) /Users/cazza/Documents/UTS/CS 2/PedestrianProject/testing_files/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 26.5ms
# ...

# %%
resultx = model11x.predict(source="testing_files/vtest.avi", save=True, project="runs/predict", name="output_vtestx")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/795) /Users/cazza/Documents/UTS/CS 2/PedestrianProject/testing_files/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 58.7ms
# video 1/1 (frame 2/795) /Users/cazza/Documents/UTS/CS 2/PedestrianProject/testing_files/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 29.3ms
# video 1/1 (frame 3/795) /Users/cazza/Documents/UTS/CS 2/PedestrianProject/testing_files/vtest.avi: 480x640 3 persons, 1 car, 1 truck, 29.6ms
# ...
